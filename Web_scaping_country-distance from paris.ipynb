# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
url="https://apprendre5minutes.wordpress.com/2022/02/27/distance-entre-paris-et-les-capitales-du-monde/"

# %%
page= requests.get(url)
soup= BeautifulSoup(page.content,"html.parser")

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="fr-FR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://apprendre5minutes.wordpress.com/xmlrpc.php" rel="pingback"/>
# <title>Distance entre Paris et les Capitales du Monde – apprendre 5 minutes</title>
# <script type="text/javascript">
#   WebFontConfig = {"google":{"families":["Lato:r:latin,latin-ext","Lato:r,i,b,bi:latin,latin-ext"]}};
#   (function() {
#     var wf = document.createElement('script');
#     wf.src = 'https://s0.wp.com/wp-content/plugins/custom-fonts/js/webfont.js';
#     wf.type = 'text/javascript';
#     wf.async = 'true';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(wf, s);
# 	})();
# ...

# %%
page=soup.findAll("li")
page
# Out:
# [<li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-2909" id="menu-item-2909"><a href="https://apprendre5minutes.wordpress.com/">Accueil</a></li>,
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2910" id="menu-item-2910"><a href="https://apprendre5minutes.wordpress.com/a-propos/">À propos</a></li>,
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7453" id="menu-item-7453"><a href="https://apprendre5minutes.wordpress.com/plan-du-site/">Plan du site</a></li>,
#  <li><a href="#capitale-la-plus-proche-de-paris">Capitale <strong>la plus proche</strong> de Paris.</a></li>,
#  <li><a href="#capitale-la-plus-eloignee-de-paris">Capitale <strong>la plus éloignée</strong> de Paris.</a></li>,
#  <li><a href="#capitales-a-moins-de-1-000-kilometres-de-paris">Capitales à <strong>moins de 1 000 kilomètres</strong> de Paris.</a></li>,
# ...

# %%
df=pd.DataFrame(page)
# Out:
# C:\Users\perso\anaconda3\lib\site-packages\pandas\core\internals\construction.py:309: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
df
# Out:
#                                                      0
# 0                                          [[Accueil]]
# 1                                         [[À propos]]
# 2                                     [[Plan du site]]
# 3          [[Capitale , [la plus proche],  de Paris.]]
# 4        [[Capitale , [la plus éloignée],  de Paris.]]
# ..                                                 ...
# 453                               [[Copier shortlink]]
# 454                            [[Signaler ce contenu]]
# 455  [\n, [\n\t\t\t\t\t\t\t\t\t\t\tVoir l’article d...
# 456                  [\n, [Gérer les abonnements], \n]
# 457                            [[Réduire cette barre]]
#
# [458 rows x 1 columns]

# %%
data = df.iloc[21:216,:]

# %%
data
# Out:
#                                                      0
# 21   [Distance Paris → Pretoria (Afrique du Sud – A...
# 22   [Distance Paris → Tirana (Albanie – Europe) = ...
# 23   [Distance Paris → Alger (Algérie – Afrique) = ...
# 24   [Distance Paris → Berlin (Allemagne – Europe) ...
# 25   [Distance Paris → Andorre-La-Vieille (Andorre ...
# ..                                                 ...
# 211  [Distance Paris → Caracas (Venezuela – Amériqu...
# 212  [Distance Paris → Hanoï (Viêt Nam – Asie) = 9 ...
# 213  [Distance Paris → Sanaa (Yémen – Asie) = 5 313...
# 214  [Distance Paris → Lusaka (Zambie – Afrique) = ...
# 215  [Distance Paris → Harare (Zimbabwe – Afrique) ...
#
# [195 rows x 1 columns]

# %%
data = data.drop(data.index[[17]])

# %%
data = data.drop(151)

# %%
data = data.drop(data.index[[146]])

# %%
table =[]
for liste in data[0]:
    res =list(map(lambda st: str.replace(st,"Distance Paris →"," "), liste))
    table.append(str(res))

# %%
table
# Out:
# ["['  Pretoria (Afrique du Sud – Afrique) = 8 684 km.']",
#  "['  Tirana (Albanie – Europe) = 1 601 km.']",
#  "['  Alger (Algérie – Afrique) = 1 914 km.']",
#  "['  Berlin (Allemagne – Europe) = 878 km.']",
#  "['  Andorre-La-Vieille (Andorre – Europe) = 709 km.']",
#  "['  Luanda (Angola – Afrique) = 6 503 km.']",
#  "['  Saint John’s (Antigua-et-Barbuda – Amérique) = 6 706 km.']",
#  "['  Riyad (Arabie saoudite – Asie) = 4 682 km.']",
#  "['  Buenos Aires (Argentine – Amérique) = 11 051 km.']",
#  "['  Erevan (Arménie – Asie) = 3 431 km.']",
#  "['  Canberra (Australie – Océanie) = 16 926 km.']",
#  "['  Vienne (Autriche – Europe) = 1 033 km.']",
#  "['  Bakou (Azerbaïdjan – Asie) = 3 813 km.']",
#  "['  Nassau (Bahamas – Amérique) = 7 207 km.']",
#  "['  Manama (Bahreïn – Asie) = 4 833 km.']",
#  "['  Dacca (Bangladesh – Asie) = 7 910 km.']",
#  "['  Bridgetown (Barbade – Amérique) = 6 875 km.']",
#  "['  Belmopan (Belize – Amérique) = 8 653 km.']",
# ...

# %%
df=pd.DataFrame(table)

# %%
df
# Out:
#                                                      0
# 0    ['  Pretoria (Afrique du Sud – Afrique) = 8 68...
# 1          ['  Tirana (Albanie – Europe) = 1 601 km.']
# 2          ['  Alger (Algérie – Afrique) = 1 914 km.']
# 3          ['  Berlin (Allemagne – Europe) = 878 km.']
# 4    ['  Andorre-La-Vieille (Andorre – Europe) = 70...
# ..                                                 ...
# 187   ['  Caracas (Venezuela – Amérique) = 7 618 km.']
# 188          ['  Hanoï (Viêt Nam – Asie) = 9 193 km.']
# 189             ['  Sanaa (Yémen – Asie) = 5 313 km.']
# 190        ['  Lusaka (Zambie – Afrique) = 7 591 km.']
# 191      ['  Harare (Zimbabwe – Afrique) = 7 940 km.']
#
# [192 rows x 1 columns]

# %%
df["Distance"] = df[0].apply(lambda x: x.split("=")[1])
df["Pays"] = df[0].apply(lambda x: x.split("=")[0])

# %%
df
# Out:
#                                                      0      Distance  \
# 0    ['  Pretoria (Afrique du Sud – Afrique) = 8 68...   8 684 km.']
# 1          ['  Tirana (Albanie – Europe) = 1 601 km.']   1 601 km.']
# 2          ['  Alger (Algérie – Afrique) = 1 914 km.']   1 914 km.']
# 3          ['  Berlin (Allemagne – Europe) = 878 km.']     878 km.']
# 4    ['  Andorre-La-Vieille (Andorre – Europe) = 70...     709 km.']
# ..                                                 ...           ...
# 187   ['  Caracas (Venezuela – Amérique) = 7 618 km.']   7 618 km.']
# 188          ['  Hanoï (Viêt Nam – Asie) = 9 193 km.']   9 193 km.']
# 189             ['  Sanaa (Yémen – Asie) = 5 313 km.']   5 313 km.']
# 190        ['  Lusaka (Zambie – Afrique) = 7 591 km.']   7 591 km.']
# 191      ['  Harare (Zimbabwe – Afrique) = 7 940 km.']   7 940 km.']
#
#                                            Pays
# 0      ['  Pretoria (Afrique du Sud – Afrique)
# ...

# %%
df['Continent']=df["Pays"].apply(lambda x: x.split("–")[1])

# %%
df['Pays']=df["Pays"].apply(lambda x: x.split("–")[0])

# %%
df['Capital']=df["Pays"].apply(lambda x: x.split("(")[0])

# %%
df['Pays']=df["Pays"].apply(lambda x: x.split("(")[1])

# %%
df
# Out:
#                                                      0      Distance  \
# 0    ['  Pretoria (Afrique du Sud – Afrique) = 8 68...   8 684 km.']
# 1          ['  Tirana (Albanie – Europe) = 1 601 km.']   1 601 km.']
# 2          ['  Alger (Algérie – Afrique) = 1 914 km.']   1 914 km.']
# 3          ['  Berlin (Allemagne – Europe) = 878 km.']     878 km.']
# 4    ['  Andorre-La-Vieille (Andorre – Europe) = 70...     709 km.']
# ..                                                 ...           ...
# 187   ['  Caracas (Venezuela – Amérique) = 7 618 km.']   7 618 km.']
# 188          ['  Hanoï (Viêt Nam – Asie) = 9 193 km.']   9 193 km.']
# 189             ['  Sanaa (Yémen – Asie) = 5 313 km.']   5 313 km.']
# 190        ['  Lusaka (Zambie – Afrique) = 7 591 km.']   7 591 km.']
# 191      ['  Harare (Zimbabwe – Afrique) = 7 940 km.']   7 940 km.']
#
#                 Pays    Continent                  Capital
# 0    Afrique du Sud     Afrique)             ['  Pretoria
# ...

# %%
tab =[]
for liste in df[0]:
    li = liste.apply(lambda x: x.split("-")[0])
    tab.append(str(li))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-c9335077f7e1> in <module>
#       1 tab =[]
#       2 for liste in df[0]:
# ----> 3     li = liste.apply(lambda x: x.split("-")[0])
#       4     tab.append(str(li))
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
tab

# %%
df[['Ville','Pays','Continent','Km']] = df[0].str.split('.', n=1, expand=True)
df

# %%
res

# %%
# new data frame with split value columns
data[1]= data[0].str.split("Paris", n = 1, expand = True)

# %%
data

# %%
df

# %%
df = pd.DataFrame()

# put complete list into DataFrame
df['Country'] = country
df.head(10)
